# %% [markdown]
# # Datapreprocessing and EDA

# %%
import pandas as pd

def load_data(filepath):
    """
    Loads the asthma dataset


    """
    return pd.read_csv(filepath)

# Load your dataset
file_path = "asthma_disease_data.csv"
asthma_df = load_data(file_path)
asthma_df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  LungFunctionFEV1  \
# 0          0.894448     5.488696      8.701003  ...          1.369051
# 1          5.897329     6.341014      5.153966  ...          2.197767
# 2          6.739367     9.196237      6.840647  ...          1.698011
# 3          1.404503     5.826532      4.253036  ...          3.032037
# 4          4.604493     3.127048      9.625799  ...          3.470589
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# 0         4.941206         0                  0               1         0
# 1         1.702393         1                  0               0         1
# 2         5.022553         1                  1               1         0
# 3         2.300159         1                  0               1         1
# 4         3.067944         1                  1               1         0
#
#    NighttimeSymptoms  ExerciseInduced  Diagnosis  DoctorInCharge
# 0                  0                1          0       Dr_Confid
# 1                  1                1          0       Dr_Confid
# 2                  1                1          0       Dr_Confid
# 3                  1                0          0       Dr_Confid
# 4                  0                1          0       Dr_Confid
#
# [5 rows x 29 columns]

# %%
asthma_df.drop(columns=["PatientID"], inplace=True)

# %%
def check_missing_values(df):
    """
    Checks and displays the count of missing values in each column of the dataset.


    """
    return df.isnull().sum()

# Display missing values
check_missing_values(asthma_df)
# Out:
# Age                       0
# Gender                    0
# Ethnicity                 0
# EducationLevel            0
# BMI                       0
# Smoking                   0
# PhysicalActivity          0
# DietQuality               0
# SleepQuality              0
# PollutionExposure         0
# PollenExposure            0
# DustExposure              0
# PetAllergy                0
# FamilyHistoryAsthma       0
# HistoryOfAllergies        0
# Eczema                    0
# HayFever                  0
# GastroesophagealReflux    0
# LungFunctionFEV1          0
# LungFunctionFVC           0
# Wheezing                  0
# ShortnessOfBreath         0
# ChestTightness            0
# Coughing                  0
# NighttimeSymptoms         0
# ExerciseInduced           0
# Diagnosis                 0
# DoctorInCharge            0
# dtype: int64

# %%
def summarize_data(df):
    """
    Provides summary statistics and data type information of the dataset.


    """
    print("\n--- Dataset Info ---")
    print(df.info())

    print("\n--- Descriptive Statistics ---")
    print(df.describe())

# Run summary
summarize_data(asthma_df)
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     2392 non-null   int64
#  1   Gender                  2392 non-null   int64
#  2   Ethnicity               2392 non-null   int64
#  3   EducationLevel          2392 non-null   int64
#  4   BMI                     2392 non-null   float64
#  5   Smoking                 2392 non-null   int64
#  6   PhysicalActivity        2392 non-null   float64
#  7   DietQuality             2392 non-null   float64
#  8   SleepQuality            2392 non-null   float64
#  9   PollutionExposure       2392 non-null   float64
#  10  PollenExposure          2392 non-null   float64
#  11  DustExposure            2392 non-null   float64
#  12  PetAllergy              2392 non-null   int64
#  13  FamilyHistoryAsthma     2392 non-null   int64
#  14  HistoryOfAllergies      2392 non-null   int64
#  15  Eczema                  2392 non-null   int64
#  16  HayFever                2392 non-null   int64
#  17  GastroesophagealReflux  2392 non-null   int64
#  18  LungFunctionFEV1        2392 non-null   float64
#  19  LungFunctionFVC         2392 non-null   float64
#  20  Wheezing                2392 non-null   int64
#  21  ShortnessOfBreath       2392 non-null   int64
#  22  ChestTightness          2392 non-null   int64
#  23  Coughing                2392 non-null   int64
#  24  NighttimeSymptoms       2392 non-null   int64
#  25  ExerciseInduced         2392 non-null   int64
#  26  Diagnosis               2392 non-null   int64
#  27  DoctorInCharge          2392 non-null   object
# dtypes: float64(9), int64(18), object(1)
# memory usage: 523.4+ KB
# None
#
# --- Descriptive Statistics ---
#                Age       Gender    Ethnicity  EducationLevel          BMI  \
# count  2392.000000  2392.000000  2392.000000     2392.000000  2392.000000
# mean     42.137960     0.493311     0.669732        1.307274    27.244877
# std      21.606655     0.500060     0.986120        0.898242     7.201628
# min       5.000000     0.000000     0.000000        0.000000    15.031803
# 25%      23.000000     0.000000     0.000000        1.000000    20.968313
# 50%      42.000000     0.000000     0.000000        1.000000    27.052202
# 75%      61.000000     1.000000     1.000000        2.000000    33.555903
# max      79.000000     1.000000     3.000000        3.000000    39.985611
#
#            Smoking  PhysicalActivity  DietQuality  SleepQuality  \
# count  2392.000000       2392.000000  2392.000000   2392.000000
# mean      0.141722          5.051786     5.022867      7.019012
# std       0.348838          2.903574     2.909980      1.732475
# min       0.000000          0.001740     0.003031      4.001437
# 25%       0.000000          2.578333     2.432043      5.498500
# 50%       0.000000          5.016881     5.115383      6.975839
# 75%       0.000000          7.540234     7.544216      8.526950
# max       1.000000          9.995809     9.999904      9.996235
#
#        PollutionExposure  ...  GastroesophagealReflux  LungFunctionFEV1  \
# count        2392.000000  ...             2392.000000       2392.000000
# mean            5.013030  ...                0.158027          2.548564
# std             2.935605  ...                0.364842          0.861809
# min             0.001022  ...                0.000000          1.000459
# 25%             2.432559  ...                0.000000          1.824113
# 50%             5.036519  ...                0.000000          2.553244
# 75%             7.630037  ...                0.000000          3.292897
# max             9.998964  ...                1.000000          3.999719
#
#        LungFunctionFVC     Wheezing  ShortnessOfBreath  ChestTightness  \
# count      2392.000000  2392.000000        2392.000000     2392.000000
# mean          3.741270     0.596154           0.500418        0.503344
# std           1.303689     0.490770           0.500104        0.500093
# min           1.500045     0.000000           0.000000        0.000000
# 25%           2.607489     0.000000           0.000000        0.000000
# 50%           3.734982     1.000000           1.000000        1.000000
# 75%           4.864121     1.000000           1.000000        1.000000
# max           5.999421     1.000000           1.000000        1.000000
#
#           Coughing  NighttimeSymptoms  ExerciseInduced    Diagnosis
# count  2392.000000        2392.000000      2392.000000  2392.000000
# mean      0.503344           0.602425         0.604933     0.051839
# std       0.500093           0.489499         0.488967     0.221749
# min       0.000000           0.000000         0.000000     0.000000
# 25%       0.000000           0.000000         0.000000     0.000000
# 50%       1.000000           1.000000         1.000000     0.000000
# 75%       1.000000           1.000000         1.000000     0.000000
# max       1.000000           1.000000         1.000000     1.000000
#
# [8 rows x 27 columns]

# %%
def encode_categorical_columns(df):
    """
    Encodes categorical string columns using one-hot encoding or label encoding as appropriate.


    """
    df_encoded = df.copy()

    # Encode Gender and Smoking if needed
    if df_encoded['Gender'].dtype == 'object':
        df_encoded['Gender'] = df_encoded['Gender'].astype('category').cat.codes
    if df_encoded['Smoking'].dtype == 'object':
        df_encoded['Smoking'] = df_encoded['Smoking'].astype('category').cat.codes

    # One-hot encode 'DoctorInCharge'
    if df_encoded['DoctorInCharge'].nunique() < 10:
        df_encoded = pd.get_dummies(df_encoded, columns=['DoctorInCharge'], drop_first=True)

    return df_encoded

# Encode and store new dataframe
asthma_encoded = encode_categorical_columns(asthma_df)
asthma_encoded.head()
# Out:
#    Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0   63       0          1               0  15.848744        0
# 1   26       1          2               2  22.757042        0
# 2   57       0          2               1  18.395396        0
# 3   40       1          2               1  38.515278        0
# 4   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  PollutionExposure  ...  \
# 0          0.894448     5.488696      8.701003           7.388481  ...
# 1          5.897329     6.341014      5.153966           1.969838  ...
# 2          6.739367     9.196237      6.840647           1.460593  ...
# 3          1.404503     5.826532      4.253036           0.581905  ...
# 4          4.604493     3.127048      9.625799           0.980875  ...
#
#    GastroesophagealReflux  LungFunctionFEV1  LungFunctionFVC  Wheezing  \
# 0                       0          1.369051         4.941206         0
# 1                       0          2.197767         1.702393         1
# 2                       0          1.698011         5.022553         1
# 3                       0          3.032037         2.300159         1
# 4                       0          3.470589         3.067944         1
#
#    ShortnessOfBreath  ChestTightness  Coughing  NighttimeSymptoms  \
# 0                  0               1         0                  0
# 1                  0               0         1                  1
# 2                  1               1         0                  1
# 3                  0               1         1                  1
# 4                  1               1         0                  0
#
#    ExerciseInduced  Diagnosis
# 0                1          0
# 1                1          0
# 2                1          0
# 3                0          0
# 4                1          0
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_correlation_matrix(df):
    """
    Plots a full correlation heatmap using all numeric features, excluding identifiers.
    """
    numeric_cols = df.select_dtypes(include=['float64', 'int64'])

    # Plot the full correlation matrix
    plt.figure(figsize=(14, 12))
    sns.heatmap(numeric_cols.corr(), annot=True, fmt=".2f", cmap='coolwarm',
                linewidths=0.5, square=True, cbar=True)
    plt.title("Full Correlation Heatmap (All Numeric Features)")
    plt.tight_layout()
    plt.show()
plot_correlation_matrix(asthma_df)

# %%
def detect_outliers(df, column):
    """
    Detects outliers in a given column using the IQR method and plots the distribution.


    """
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR)]

    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Outlier Detection for {column}')
    plt.tight_layout()
    plt.show()

    return outliers.index.tolist()

# Example outlier detection for BMI
outlier_indices = detect_outliers(asthma_encoded, "BMI")
print(f"Outliers found in 'BMI': {len(outlier_indices)}")
# Out:
# Outliers found in 'BMI': 0

# %%
# Plot histograms for all numeric features
asthma_df.hist(bins=30, figsize=(18, 14), color='skyblue', edgecolor='black')
plt.suptitle("Histograms of Numerical Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Example: Boxplot of BMI vs Diagnosis
sns.boxplot(x="Diagnosis", y="BMI", data=asthma_df)
plt.title("BMI vs Asthma Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("BMI")
plt.show()

# %%
# If needed: visualize pairwise relationships among top features
top_features = ['BMI', 'LungFunctionFEV1', 'PollutionExposure', 'Diagnosis']
sns.pairplot(asthma_encoded[top_features], hue="Diagnosis")
plt.suptitle("Pairplot of Key Predictors vs Diagnosis", y=1.02)
plt.show()

# %% [markdown]
# # model training and feature selection

# %%
# Recreate feature and target variables (if needed)
X = asthma_encoded.drop(columns=["Diagnosis"])
y = asthma_encoded["Diagnosis"]

# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,stratify = y, test_size=0.3,  shuffle=True, random_state = 42
)

# %%
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=42)
X_train_bal, y_train_bal = smote_enn.fit_resample(X_train, y_train)



# Plot class distribution before and after SMOTE
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Before SMOTE
sns.countplot(x=y_train, ax=axes[0])
axes[0].set_title("Class Distribution Before SMOTE")
axes[0].set_xlabel("Diagnosis")
axes[0].set_ylabel("Count")

# After SMOTE
sns.countplot(x=y_train_bal, ax=axes[1])
axes[1].set_title("Class Distribution After SMOTE")
axes[1].set_xlabel("Diagnosis")
axes[1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
# === Imports ===
from xgboost import XGBClassifier
from sklearn.svm import SVC
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix, RocCurveDisplay
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# === MODEL 1: XGBoost with class weighting ===
scale_pos_weight = len(y_train_bal[y_train_bal == 0]) / len(y_train_bal[y_train_bal == 1])
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', scale_pos_weight=scale_pos_weight)
model_xgb.fit(X_train_bal, y_train_bal)
y_proba_xgb = model_xgb.predict_proba(X_test)[:, 1]
y_pred_xgb = (y_proba_xgb >= 0.3).astype(int)  # Threshold tuning

# === MODEL 2: SVM with class weighting ===
model_svm =  SVC(kernel='linear', class_weight='balanced', probability=True)

model_svm.fit(X_train_bal, y_train_bal)
y_proba_svm = model_svm.predict_proba(X_test)[:, 1]
y_pred_svm = (y_proba_svm >= 0.3).astype(int)  # Threshold tuning

# === MODEL 3: Improved ANN with class weighting ===
# Compute class weights
cw = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_bal), y=y_train_bal)
cw_dict = dict(enumerate(cw))

model_ann = Sequential([
    Dense(128, input_dim=X_train_bal.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model_ann.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train with class weights
history = model_ann.fit(
    X_train_bal, y_train_bal,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    class_weight=cw_dict
)

# ANN predictions
y_proba_ann = model_ann.predict(X_test).flatten()
y_pred_ann = (y_proba_ann >= 0.3).astype(int)  # Threshold tuning

# === Evaluation Function ===
def evaluate_model(name, y_test, y_pred, y_proba):
    print(f"\n{name} Classification Report:")
    report = classification_report(y_test, y_pred, output_dict=True)
    f1 = report['1']['f1-score']
    recall = report['1']['recall']
    print(f"F1 Score: {f1:.4f}")
    print(f"Recall  : {recall:.4f}")

    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=[0, 1], yticklabels=[0, 1])
    plt.title(f"{name} - Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

# === Evaluate All Models ===
evaluate_model("XGBoost (Weighted + Threshold 0.3)", y_test, y_pred_xgb, y_proba_xgb)
evaluate_model("SVM (Weighted + Threshold 0.3)", y_test, y_pred_svm, y_proba_svm)
evaluate_model("ANN (Weighted + Threshold 0.3)", y_test, y_pred_ann, y_proba_ann)

# === ROC Curve for All Models ===
plt.figure(figsize=(8, 6))
RocCurveDisplay.from_predictions(y_test, y_proba_xgb, name="XGBoost")
RocCurveDisplay.from_predictions(y_test, y_proba_svm, name="SVM")
RocCurveDisplay.from_predictions(y_test, y_proba_ann, name="ANN (Improved)")
plt.plot([0, 1], [0, 1], "k--")
plt.title("ROC Curve - XGBoost vs SVM vs ANN (Improved)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [09:53:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5073 - loss: 1.3034 - val_accuracy: 0.2078 - val_loss: 0.7479
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5052 - loss: 0.7840 - val_accuracy: 0.0784 - val_loss: 0.8447
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5158 - loss: 0.7385 - val_accuracy: 0.0098 - val_loss: 0.8677
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5139 - loss: 0.7196 - val_accuracy: 0.0804 - val_loss: 0.8651
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5337 - loss: 0.6991 - val_accuracy: 0.1314 - val_loss: 0.8117
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5329 - loss: 0.7106 - val_accuracy: 0.2882 - val_loss: 0.7071
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5330 - loss: 0.6820 - val_accuracy: 0.7510 - val_loss: 0.6335
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5887 - loss: 0.6497 - val_accuracy: 0.4961 - val_loss: 0.6869
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6335 - loss: 0.6233 - val_accuracy: 0.6471 - val_loss: 0.5974
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.5796 - val_accuracy: 0.6412 - val_loss: 0.6116
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7236 - loss: 0.5397 - val_accuracy: 0.9451 - val_loss: 0.3546
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7482 - loss: 0.5020 - val_accuracy: 0.9412 - val_loss: 0.3377
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7900 - loss: 0.4615 - val_accuracy: 0.8294 - val_loss: 0.4280
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7992 - loss: 0.4424 - val_accuracy: 0.8275 - val_loss: 0.3989
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - loss: 0.4082 - val_accuracy: 0.8784 - val_loss: 0.3058
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8248 - loss: 0.3985 - val_accuracy: 0.9490 - val_loss: 0.2212
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8544 - loss: 0.3899 - val_accuracy: 0.8745 - val_loss: 0.3219
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8437 - loss: 0.3637 - val_accuracy: 0.9196 - val_loss: 0.2491
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8440 - loss: 0.3656 - val_accuracy: 0.9451 - val_loss: 0.1910
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8845 - loss: 0.3317 - val_accuracy: 0.9216 - val_loss: 0.2473
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8713 - loss: 0.3356 - val_accuracy: 0.9471 - val_loss: 0.1769
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8627 - loss: 0.3159 - val_accuracy: 0.9392 - val_loss: 0.1776
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8878 - loss: 0.3211 - val_accuracy: 0.9216 - val_loss: 0.2001
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8754 - loss: 0.3044 - val_accuracy: 0.9412 - val_loss: 0.1926
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8838 - loss: 0.3030 - val_accuracy: 0.9588 - val_loss: 0.1597
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8855 - loss: 0.2948 - val_accuracy: 0.9510 - val_loss: 0.1592
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8834 - loss: 0.3001 - val_accuracy: 0.9392 - val_loss: 0.1790
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8934 - loss: 0.2582 - val_accuracy: 0.9686 - val_loss: 0.1289
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9013 - loss: 0.2973 - val_accuracy: 0.9529 - val_loss: 0.1389
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.2659 - val_accuracy: 0.9118 - val_loss: 0.2199
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8799 - loss: 0.2878 - val_accuracy: 0.9647 - val_loss: 0.1032
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8990 - loss: 0.2720 - val_accuracy: 0.9686 - val_loss: 0.0893
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9034 - loss: 0.2688 - val_accuracy: 0.9627 - val_loss: 0.1322
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9094 - loss: 0.2251 - val_accuracy: 0.9667 - val_loss: 0.1181
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.2427 - val_accuracy: 0.9804 - val_loss: 0.0901
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9177 - loss: 0.2225 - val_accuracy: 0.9373 - val_loss: 0.1701
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9058 - loss: 0.2330 - val_accuracy: 0.9863 - val_loss: 0.0672
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - loss: 0.2250 - val_accuracy: 0.9647 - val_loss: 0.1047
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9300 - loss: 0.2023 - val_accuracy: 0.8902 - val_loss: 0.2134
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9242 - loss: 0.2007 - val_accuracy: 0.9373 - val_loss: 0.1571
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9298 - loss: 0.1871 - val_accuracy: 0.9608 - val_loss: 0.1325
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9146 - loss: 0.2179 - val_accuracy: 0.9745 - val_loss: 0.0808
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9170 - loss: 0.2065 - val_accuracy: 0.9824 - val_loss: 0.0823
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9377 - loss: 0.1715 - val_accuracy: 0.9843 - val_loss: 0.0833
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9439 - loss: 0.1692 - val_accuracy: 0.9706 - val_loss: 0.1148
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.1705 - val_accuracy: 0.9627 - val_loss: 0.1342
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9334 - loss: 0.1859 - val_accuracy: 0.9843 - val_loss: 0.0515
# Epoch 48/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.1725 - val_accuracy: 0.9824 - val_loss: 0.0835
# Epoch 49/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9347 - loss: 0.1635 - val_accuracy: 0.9706 - val_loss: 0.0879
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9354 - loss: 0.1661 - val_accuracy: 0.9824 - val_loss: 0.0745
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# XGBoost (Weighted + Threshold 0.3) Classification Report:
# F1 Score: 0.0672
# Recall  : 0.1081
# SVM (Weighted + Threshold 0.3) Classification Report:
# F1 Score: 0.0972
# Recall  : 0.3784
# ANN (Weighted + Threshold 0.3) Classification Report:
# F1 Score: 0.1102
# Recall  : 0.1892

# %%
# === Plot epoch-wise training & validation metrics ===
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Epoch-wise Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Epoch-wise Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.suptitle("Training Progress of ANN (Improved)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pandas as pd

# Function to calculate and return evaluation metrics
def get_metrics(name, y_true, y_pred, y_proba):
    return {
        "Model": name,
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, zero_division=0),
        "Recall": recall_score(y_true, y_pred),
        "F1 Score": f1_score(y_true, y_pred),
        "ROC AUC": roc_auc_score(y_true, y_proba)
    }

# Gather metrics for all models
evaluation_results = [
    get_metrics("XGBoost", y_test, y_pred_xgb, y_proba_xgb),
    get_metrics("SVM", y_test, y_pred_svm, y_proba_svm),
    get_metrics("ANN (Improved)", y_test, y_pred_ann, y_proba_ann)
]

# Display in DataFrame format
evaluation_df = pd.DataFrame(evaluation_results).set_index("Model")
print("\n=== Model Performance Summary ===")
print(evaluation_df.round(4))
# Out:
# === Model Performance Summary ===
#                 Accuracy  Precision  Recall  F1 Score  ROC AUC
# Model
# XGBoost           0.8454     0.0488  0.1081    0.0672   0.5051
# SVM               0.6379     0.0558  0.3784    0.0972   0.5473
# ANN (Improved)    0.8426     0.0778  0.1892    0.1102   0.5353

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
xgb_params = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1]
}

xgb_model = XGBClassifier(eval_metric='logloss')

# Grid Search
xgb_grid = GridSearchCV(estimator=xgb_model, param_grid=xgb_params, cv=5, scoring='f1', verbose=2, n_jobs=-1)
xgb_grid.fit(X_train_bal, y_train_bal)

print("Best XGBoost Parameters:", xgb_grid.best_params_)
best_xgb = xgb_grid.best_estimator_

# Predict again
y_pred_xgb = best_xgb.predict(X_test)
y_proba_xgb = best_xgb.predict_proba(X_test)[:, 1]
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best XGBoost Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}

# %%
# Define parameter grid
svm_params = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

svm_model = SVC(probability=True, random_state=42)

# Grid Search
svm_grid = GridSearchCV(estimator=svm_model, param_grid=svm_params, cv=5, scoring='f1', verbose=2, n_jobs=-1)
svm_grid.fit(X_train_bal, y_train_bal)

print("Best SVM Parameters:", svm_grid.best_params_)
best_svm = svm_grid.best_estimator_

# Predict again
y_pred_svm = best_svm.predict(X_test)
y_proba_svm = best_svm.predict_proba(X_test)[:, 1]
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best SVM Parameters: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score
)
import pandas as pd

# === Evaluation Function ===
def evaluate_model_metrics(name, y_true, y_pred, y_proba):
    return {
        "Model": name,
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, zero_division=0),
        "Recall": recall_score(y_true, y_pred),
        "F1 Score": f1_score(y_true, y_pred),
        "ROC AUC": roc_auc_score(y_true, y_proba)
    }

# === Run Evaluation for XGBoost and SVM ===
metrics_summary = [
    evaluate_model_metrics("XGBoost (Tuned)", y_test, y_pred_xgb, y_proba_xgb),
    evaluate_model_metrics("SVM (Tuned)", y_test, y_pred_svm, y_proba_svm)
]

# === Display as Table ===
evaluation_df = pd.DataFrame(metrics_summary).set_index("Model")
print("\n Fine-Tuned Model Evaluation Summary:\n")
print(evaluation_df.round(4))
# Out:
#  Fine-Tuned Model Evaluation Summary:
#
#                  Accuracy  Precision  Recall  F1 Score  ROC AUC
# Model
# XGBoost (Tuned)    0.8802     0.0702  0.1081    0.0851   0.5097
# SVM (Tuned)        0.8997     0.0270  0.0270    0.0270   0.4224

# %%
import shap

# Initialize the TreeExplainer for XGBoost
explainer = shap.Explainer(best_xgb, X_test)

# Calculate SHAP values
shap_values = explainer(X_test)

# %%
# Summary plot of feature importances
shap.summary_plot(shap_values, X_test)

# %%
# Explain a single test example (e.g., index 0)
shap.plots.waterfall(shap_values[0])
